# %%
from Main import run, EDF
run()

f"number of processes: {len(EDF.list_of_processes['old'])}"
# Out:
# 'number of processes: 1610'

# %%
from Main import FCFS
print(FCFS)
# Out:
# --- FCFS  ---
# total distance:  6550390
# unhandeled processes: 0
# 3278714.83

# %%
from Main import SSTF
print(SSTF)
# Out:
# --- SSTF  ---
# total distance:  636620
# unhandeled processes: 0
# 511029.55

# %%
from Main import SCAN
print(SCAN)
# Out:
# --- SCAN  ---
# total distance:  20051
# unhandeled processes: 0
# 8031.61

# %%
from Main import C_SCAN
print(C_SCAN)
# Out:
# --- C_SCAN  ---
# total distance:  35629
# unhandeled processes: 0
# 6414.33

# %%
print(EDF)
# Out:
# --- EDF  ---
# total distance:  4213879
# unhandeled processes: 279
# 2407268.58
